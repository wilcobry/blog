# %%
import pandas as pd
import statsmodels.api as sm
import seaborn as sns

# %%
df = pd.read_csv('Data/Salary_dataset.csv')
df = df.drop(df.columns[0], axis=1)
part_df = df.head()

html_table = part_df.to_html()
with open("kaggle_table.html", "w") as f:
  f.write(html_table)

# %%
df.head()
sns.scatterplot(x = 'YearsExperience', y = 'Salary', data = df)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
experience = df['YearsExperience']
salary = df['Salary']

experience = sm.add_constant(experience)

# %%
model = sm.OLS(salary, experience)
results = model.fit()
new_string = f'R-squared: {results.rsquared} \nP-value: {results.f_pvalue}'
html_string = f"<html><body><pre>{new_string}</pre></body></html>"
with open("regression_string1.html", "w") as f:
  f.write(html_string)
